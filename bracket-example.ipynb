# %%
import simplejson as json
import os

for key, value in json.load(open("local.settings.json"))["Values"].items():
    os.environ[key] = str(value)

# %%
from libs.data import register_binding
register_binding(
    "an_sql_server",
    "Structured",
    "sql",
    url=os.environ["DATABIND_SQL_GENERAL"],
    schemas=["esquire", "dbo"],
)

# %%
from libs.data import from_bind
from libs.data.structured import StructuredProvider

provider = from_bind("an_sql_server")
if provider and isinstance(provider, StructuredProvider):
    qf = provider["esquire.geoframes"]
    query = qf[qf["esq_id"] != None]
    display(query)
# Out:
# SELECT esquire.geoframes.id as esquire_geoframes_id,
#        esquire.geoframes.esq_id as esquire_geoframes_esq_id,
#        (esquire.geoframes.geography).stasbinary() as esquire_geoframes_geography,
#        esquire.geoframes.notes as esquire_geoframes_notes,
#        esquire.geoframes.location_id as esquire_geoframes_location_id,
#        esquire.geoframes.type_id as esquire_geoframes_type_id
# FROM   esquire.geoframes
# WHERE  esquire.geoframes.esq_id is not null

# %%
len(query)
# Out:
# 25591

# %%
query.to_pandas()
# Out:
#                        esquire_geoframes_id esquire_geoframes_esq_id
# 0      46c26d79-5b32-4fe0-9fee-0008c9d05ca4                 EF~07264  \
# 1      df706292-385d-42c2-ab7f-00105aacf7e3                 EO~00223
# 2      e4fd7e6c-04e1-498f-8867-001098bb2604                 EF~01914
# 3      d1e465bc-5dde-477e-86e4-0014368902c8                 EF~19537
# 4      46f073cd-6011-480b-80a4-0014fd427b0e                 ER~00040
# ...                                     ...                      ...
# 25586  11a3fd3c-a3e7-43ad-9b0a-fffaa8c77099                 EF~00694
# 25587  b59eb451-1c51-4c3f-a6d5-fffbfcdd2651                 EF~19856
# 25588  944b90cb-b67a-4b8f-8a8a-fffd328cc591                 EF~10902
# 25589  59bbb3b9-b7ff-4719-951a-fffe884fb99d                 EF~16106
# 25590  8ae83446-f56a-4f75-ae82-fffffba47de5                 EF~13769
#
#                              esquire_geoframes_geography
# 0      b'\x01\x03\x00\x00\x00\x01\x00\x00\x00\x06\x00...  \
# 1      b'\x01\x03\x00\x00\x00\x01\x00\x00\x00\x0c\x00...
# 2      b'\x01\x03\x00\x00\x00\x01\x00\x00\x00\x05\x00...
# 3      b"\x01\x03\x00\x00\x00\x01\x00\x00\x00\x07\x00...
# 4      b'\x01\x03\x00\x00\x00\x01\x00\x00\x00\x07\x00...
# ...                                                  ...
# 25586  b'\x01\x03\x00\x00\x00\x01\x00\x00\x00\x06\x00...
# 25587  b'\x01\x03\x00\x00\x00\x01\x00\x00\x00\x05\x00...
# 25588  b'\x01\x03\x00\x00\x00\x01\x00\x00\x00\x08\x00...
# 25589  b"\x01\x03\x00\x00\x00\x01\x00\x00\x00\x05\x00...
# 25590  b'\x01\x03\x00\x00\x00\x01\x00\x00\x00\x05\x00...
#
#                esquire_geoframes_notes         esquire_geoframes_location_id
# 0                    Americas Mattress                                  None  \
# 1                  Bloomfield Hills CC  6b5a60ba-8ebb-43e7-a072-55c7a0f619e0
# 2             Bassett Home Furnishings  8cb5064a-c098-44d1-89fa-ca4324674200
# 3                        Mattress Firm  aed4ba4c-4473-4e03-a355-50c9ecc38e54
# 4                               Subway  cec0b2df-0e14-4652-9643-9b4b0d12009f
# ...                                ...                                   ...
# 25586          Buddy s Home Furnishing  dd03196d-d55d-40f0-bae0-e1022b4f1a35
# 25587                          Aaron's  d58be3f4-ab42-4055-bdb3-82644cd014e5
# 25588  304 Stillwater Avenue Furniture  aee47cf3-8169-483e-aefe-29ed66fb027f
# 25589                          Aaron's  e8bad2c2-c8f5-448e-8890-b1bcd60e65a4
# 25590                Schewel Furniture  4279e7d0-8793-4a4a-b75f-270117250bfc
#
#                   esquire_geoframes_type_id
# 0                                      None
# 1      d70fcd71-a66a-448d-90cc-f0967098fe16
# 2      d70fcd71-a66a-448d-90cc-f0967098fe16
# 3      d70fcd71-a66a-448d-90cc-f0967098fe16
# 4      d70fcd71-a66a-448d-90cc-f0967098fe16
# ...                                     ...
# 25586  d70fcd71-a66a-448d-90cc-f0967098fe16
# 25587  d70fcd71-a66a-448d-90cc-f0967098fe16
# 25588  d70fcd71-a66a-448d-90cc-f0967098fe16
# 25589  d70fcd71-a66a-448d-90cc-f0967098fe16
# 25590  d70fcd71-a66a-448d-90cc-f0967098fe16
#
# [25591 rows x 6 columns]
